# %% [markdown]
# <a href="https://colab.research.google.com/github/mlingley/portfolio/blob/main/Transpose_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\malin\Downloads\metacritic_games.csv')
df
# Out:
#    Unnamed: 0.1    Unnamed: 0                0  \
# 0             0         Title  Last Train Home
# 1             1  Release_date     Nov 28, 2023
# 2             2     Metascore               83
# 3             3    User_score              7.3
#
#                                   1                2             3  \
# 0  Call of Duty: Modern Warfare III  Super Mario RPG  Alan Wake II
# 1                      Nov 10, 2023     Nov 17, 2023  Oct 27, 2023
# 2                                56               84            88
# 3                               1.9              8.1           8.9
#
#                   4                  5  \
# 0  SteamWorld Build  Persona 5 Tactica
# 1       Dec 1, 2023       Nov 17, 2023
# 2                73                 75
# 3               tbd                7.8
#
#                                                    6                      7  \
# 0  Like a Dragon Gaiden: The Man Who Erased His Name  Marvel's Spider-Man 2
# ...

# %%
df_transposed = df.T
df_transposed
# Out:
#                                                        0             1  \
# Unnamed: 0.1                                           0             1
# Unnamed: 0                                         Title  Release_date
# 0                                        Last Train Home  Nov 28, 2023
# 1                       Call of Duty: Modern Warfare III  Nov 10, 2023
# 2                                        Super Mario RPG  Nov 17, 2023
# ...                                                  ...           ...
# 12125                          Operencia: The Stolen Sun  Mar 29, 2019
# 12126                                   Empire Earth III   Nov 6, 2007
# 12127                               Frozen Synapse Prime  Sep 23, 2014
# 12128         Pirates of the Caribbean: Dead Man's Chest  Jun 27, 2006
# 12129                                   Caveman Warriors   Dec 5, 2017
#
#                       2           3
# Unnamed: 0.1          2           3
# Unnamed: 0    Metascore  User_score
# ...

# %%
df_transposed.to_csv(r"C:\Users\malin\Downloads\metacritic_games1.csv", index=False)
